# %% [markdown]
# For this demo, we will use the [MIT Restaurant Corpus](https://groups.csail.mit.edu/sls/downloads/restaurant/) -- a dataset of transcriptions of spoken utterances about restaurants.
#
# The dataset has following entity types:
#
# * 'B-Rating'
# * 'I-Rating',
# * 'B-Amenity',
# * 'I-Amenity',
# * 'B-Location',
# * 'I-Location',
# * 'B-Restaurant_Name',
# * 'I-Restaurant_Name',
# * 'B-Price',
# * 'B-Hours',
# * 'I-Hours',
# * 'B-Dish',
# * 'I-Dish',
# * 'B-Cuisine',
# * 'I-Price',
# * 'I-Cuisine'
#
# Let us load the dataset and see what are we working with.

# %%
with open('../Dataset/sent_train', 'r') as train_sent_file:
  train_sentences = train_sent_file.readlines()

with open('../Dataset/label_train', 'r') as train_labels_file:
  train_labels = train_labels_file.readlines()

with open('../Dataset/sent_test', 'r') as test_sent_file:
  test_sentences = test_sent_file.readlines()

with open('../Dataset/label_test', 'r') as test_labels_file:
  test_labels = test_labels_file.readlines()

# %% [markdown]
# Let us see some example data points.

# %%
# Print the 6th sentence in the test set i.e. index value 5.
print(test_sentences[5])

# Print the labels of this sentence
print(test_labels[5])
# Out:
# any good ice cream parlors around
#
# O B-Rating B-Cuisine I-Cuisine I-Cuisine B-Location

# %% [markdown]
# #Defining Features for Custom NER

# %% [markdown]
# First, let us install the required modules.

# %%
# Install pycrf and crfsuit packages using pip command
# !pip install pycrf
# !pip install sklearn-crfsuite
# Out:
# Collecting pycrf
#   Downloading pycrf-0.0.1.tar.gz (1.1 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: pycrf
#   Building wheel for pycrf (pyproject.toml): started
#   Building wheel for pycrf (pyproject.toml): finished with status 'done'
#   Created wheel for pycrf: filename=pycrf-0.0.1-py3-none-any.whl size=1907 sha256=b614d6c1185d298c49fa391e5c0cb0704684c11ad9ebb3a584c57ad1f8c993ab
#   Stored in directory: c:\users\andhondi\appdata\local\pip\cache\wheels\fd\3a\fb\e4d15c9c2b169f43811b23a863ee9717ff3eda5d2301789043
# Successfully built pycrf
# Installing collected packages: pycrf
# Successfully installed pycrf-0.0.1
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/d1/2a/a97ef025347ae0e20b1644bdc98c704aae0a5719aaac0277ec2270f98c1f/pycrf-0.0.1.tar.gz
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting python-crfsuite>=0.9.7 (from sklearn-crfsuite)
#   Downloading python_crfsuite-0.9.11-cp310-cp310-win_amd64.whl.metadata (4.4 kB)
# Collecting scikit-learn>=0.24.0 (from sklearn-crfsuite)
#   Downloading scikit_learn-1.7.1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting tabulate>=0.4.2 (from sklearn-crfsuite)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tqdm>=2.0 in c:\users\andhondi\appdata\local\programs\python\python310\lib\site-packages (from sklearn-crfsuite) (4.67.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\andhondi\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite) (2.2.6)
# Collecting scipy>=1.8.0 (from scikit-learn>=0.24.0->sklearn-crfsuite)
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\andhondi\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.24.0->sklearn-crfsuite) (1.5.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.24.0->sklearn-crfsuite)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\andhondi\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=2.0->sklearn-crfsuite) (0.4.6)
# Downloading sklearn_crfsuite-0.5.0-py2.py3-none-any.whl (10 kB)
# Downloading python_crfsuite-0.9.11-cp310-cp310-win_amd64.whl (301 kB)
# Downloading scikit_learn-1.7.1-cp310-cp310-win_amd64.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.9 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/8.9 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/8.9 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.9 MB 1.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/8.9 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.6/8.9 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/8.9 MB 1.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.9/8.9 MB 2.0 MB/s eta 0:00:03
#    ------------------ --------------------- 4.2/8.9 MB 2.0 MB/s eta 0:00:03
#    --------------------- ------------------ 4.7/8.9 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.2/8.9 MB 2.0 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/8.9 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 2.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.6/8.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 7.1/8.9 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/8.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.9 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.9 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.1/8.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 8.4/8.9 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/8.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 1.6 MB/s eta 0:00:00
# Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, tabulate, scipy, python-crfsuite, scikit-learn, sklearn-crfsuite
#
#    ------ --------------------------------- 1/6 [tabulate]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    -------------------- ------------------- 3/6 [python-crfsuite]
#    -------------------- ------------------- 3/6 [python-crfsuite]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    -------------------------- ------------- 4/6 [scikit-learn]
#    --------------------------------- ------ 5/6 [sklearn-crfsuite]
#    ---------------------------------------- 6/6 [sklearn-crfsuite]
#
# Successfully installed python-crfsuite-0.9.11 scikit-learn-1.7.1 scipy-1.15.3 sklearn-crfsuite-0.5.0 tabulate-0.9.0 threadpoolctl-3.6.0

# %% [markdown]
# We will now start with computing features for our input sequences.

# %% [markdown]
# We have defined the following features for CRF model building:
#
# - f1 = input word is in lower case;
# - f2 = last 3 characters of word;
# - f3 = last 2 characers of word;
# - f4 = 1; if the word is in uppercase, 0 otherwise;
# - f5 = 1; if word is a number; otherwise, 0
# - f6= 1; if the word starts with a capital letter; otherwise, 0

# %%
#Define a function to get the above defined features for a word.

def getFeaturesForOneWord(sentence, pos):
  word = sentence[pos]

  features = [
    'word.lower=' + word.lower(), # serves as word id
    'word[-3:]=' + word[-3:],     # last three characters
    'word[-2:]=' + word[-2:],     # last two characters
    'word.isupper=%s' % word.isupper(),  # is the word in all uppercase
    'word.isdigit=%s' % word.isdigit(),  # is the word a number
    'words.startsWithCapital=%s' % word[0].isupper() # is the word starting with a capital letter
  ]

  if(pos > 0):
    prev_word = sentence[pos-1]
    features.extend([
    'prev_word.lower=' + prev_word.lower(), 
    'prev_word.isupper=%s' % prev_word.isupper(),
    'prev_word.isdigit=%s' % prev_word.isdigit(),
    'prev_words.startsWithCapital=%s' % prev_word[0].isupper()
  ])
  else:
    features.append('BEG') # feature to track begin of sentence 

  if(pos == len(sentence)-1):
    features.append('END') # feature to track end of sentence

  return features

# %% [markdown]
# #Computing Features

# %% [markdown]
# Define a function to get features for a sentence using the already defined 'getFeaturesForOneWord' function

# %%
# Define a function to get features for a sentence 
# using the 'getFeaturesForOneWord' function.
def getFeaturesForOneSentence(sentence):
  sentence_list = sentence.split()
  return [getFeaturesForOneWord(sentence_list, pos) for pos in range(len(sentence_list))]

# %% [markdown]
# Define function to get the labels for a sentence.

# %%
# Define a function to get the labels for a sentence.
def getLabelsInListForOneSentence(labels):
  return labels.split()

# %% [markdown]
# Example features for a sentence

# %%
# Apply function 'getFeaturesForOneSentence' to get features on a single sentence which is at index value 5 in train_sentences
example_sentence = train_sentences[3]
print(example_sentence)

features = getFeaturesForOneSentence(example_sentence)
features[2]
# Out:
# 98 hong kong restaurant reasonable prices
# ['word.lower=kong',
#  'word[-3:]=ong',
#  'word[-2:]=ng',
#  'word.isupper=False',
#  'word.isdigit=False',
#  'words.startsWithCapital=False',
#  'prev_word.lower=hong',
#  'prev_word.isupper=False',
#  'prev_word.isdigit=False',
#  'prev_words.startsWithCapital=False']

# %% [markdown]
# Get the features for sentences of X_train and X_test and get the labels of Y_train and Y_test data.

# %%
X_train = [getFeaturesForOneSentence(sentence) for sentence in train_sentences]
Y_train = [getLabelsInListForOneSentence(labels) for labels in train_labels]

X_test = [getFeaturesForOneSentence(sentence) for sentence in test_sentences]
Y_test = [getLabelsInListForOneSentence(labels) for labels in test_labels]

# %% [markdown]
# #CRF Model Training
#
#  Now we have all the information we need to train our CRF. Let us see how we can do that.

# %%
import sklearn_crfsuite

from sklearn_crfsuite import metrics

# %% [markdown]
# We create a CRF object and passtraining data to it. The model then "trains" and learns the weights for feature functions.

# %%
# Build the CRF model.
crf = sklearn_crfsuite.CRF(max_iterations=100)
crf.fit(X_train, Y_train)
# Out:
# CRF(max_iterations=100)

# %% [markdown]
# #Model Testing and Evaluation
# The model is trained, let us now see how good it performs on the test data.

# %%
# Calculate the f1 score using the test data
Y_pred = crf.predict(X_test)
metrics.flat_f1_score(Y_test, Y_pred, average='weighted')
# Out:
# 0.8744963078323298

# %%
# Print the orginal labels and predicted labels for the sentence  in test data, which is at index value 10.
id = 10
print("Sentence:",test_sentences[id])
print("Orig Labels:", Y_test[id])
print("Pred Labels:", Y_pred[id])
# Out:
# Sentence: any places around here that has a nice view
#
# Orig Labels: ['O', 'O', 'B-Location', 'I-Location', 'O', 'O', 'O', 'B-Amenity', 'I-Amenity']
# Pred Labels: ['O', 'O', 'B-Location', 'I-Location', 'O', 'O', 'O', 'B-Amenity', 'I-Amenity']

# %% [markdown]
# #Transitions Learned by CRF

# %%
from util import print_top_likely_transitions
from util import print_top_unlikely_transitions

# %%
print_top_likely_transitions(crf.transition_features_)
# Out:
# B-Restaurant_Name -> I-Restaurant_Name 6.780881
# B-Location -> I-Location 6.707919
# B-Amenity -> I-Amenity 6.684323
# I-Location -> I-Location 6.449200
# I-Amenity -> I-Amenity 6.184843
# B-Dish -> I-Dish  5.921927
# B-Hours -> I-Hours 5.885215
# I-Restaurant_Name -> I-Restaurant_Name 5.861396
# B-Cuisine -> I-Cuisine 5.559378
# I-Hours -> I-Hours 5.433907

# %%
print_top_unlikely_transitions(crf.transition_features_)
# Out:
# B-Price -> B-Location -0.642258
# I-Location -> B-Dish  -0.727622
# I-Dish -> B-Cuisine -0.827604
# I-Price -> B-Location -0.886210
# I-Hours -> O       -0.889270
# B-Restaurant_Name -> B-Cuisine -0.943063
# I-Rating -> O       -0.949891
# I-Price -> O       -0.951508
# I-Restaurant_Name -> B-Dish  -1.098086
# I-Restaurant_Name -> B-Cuisine -1.127919
